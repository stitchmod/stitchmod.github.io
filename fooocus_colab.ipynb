# %%
# 1. Подготовка окружения и фикс конфликтов numpy
# !pip install --upgrade pip
# !pip install pygit2==1.15.1 numpy==1.26.4

# 2. Клонирование репозитория (если еще не клонирован)
# %cd /content
# !rm -rf /content/Fooocus # Опционально: удаляет старую папку, если хочешь чистую установку
# !git clone https://github.com/lllyasviel/Fooocus.git

# 3. Установка зависимостей самого Fooocus
# %cd /content/Fooocus
# !pip install -r requirements_versions.txt

# 4. Запуск с исправлением путей
# !python entry_with_update.py --share --always-high-vram
